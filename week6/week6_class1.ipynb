# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
police = pd.read_csv('../data/week6/sqf-2016.csv') #gives a warning about memory
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (0,1,2,3,4,8,18,19,73,74,84,85,86,103,110,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
police.head(10)
# Out:
#    year pct ser_num datestop timestop recstat inout trhsloc perobs  \
# 0  2016  41      22  2072016      100       A     O       P      1
# 1  2016  10      22  2182016       30       1     O       P      8
# 2  2016  66       1  1012016       30       1     I       P      2
# 3  2016  47      18  1012016       40       1     O       H      1
# 4  2016  79       1  1012016       50       1     O       P      3
# 5  2016  73       1  1012016      100       1     O       P      1
# 6  2016  43       6  1012016      130       1     O       P      1
# 7  2016  67       3  1012016      135       1     O       P      1
# 8  2016  43      12  1012016      210       1     O       P      1
# 9  2016  73       2  1012016      210       1     O       P      2
#
#       crimsusp   ...    zip addrpct sector beat post   xcoord   ycoord  \
# 0         BURG   ...             41      B    2       1013353   234000
# 1  MISDEMEANOR   ...             10      D             983478   212373
# ...

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12405 entries, 0 to 12404
# Columns: 112 entries, year to detailCM
# dtypes: object(112)
# memory usage: 10.6+ MB

# %%
police.groupby('pct').count().crimsusp.nlargest(10).plot(kind = 'bar'); 
#counting instances of a precinct in the data set. 
#We're using the crimsusp column to count instances, but could use anything else

# %%
police.groupby('crimsusp').count().pct.nlargest(10).plot(kind = 'bar');

# %%
police.groupby('pct')

# %%
police.groupby('pct').sum()
# Out:
#                                                   year  \
# pct
# 1                                               106848
# 5                                               161280
# 6                                                62496
# 7                                               106848
# 9                                               161280
# 10                                              131040
# 13                                              187488
# 14                                              243936
# 17                                               76608
# 18                                              197568
# 19                                              183456
# 20                                               68544
# 22                                               48384
# 23                                              570528
# 24                                              205632
# 25                                              419328
# ...

# %%
police.groupby('pct').count().crimsusp
# Out:
# pct
# 1      53
# 5      80
# 6      31
# 7      53
# 9      80
# 10     65
# 13     93
# 14    121
# 17     38
# 18     98
# 19     91
# 20     34
# 22     24
# 23    283
# 24    102
# 25    208
# 26     51
# 28     82
# 30     94
# 32    172
# 33     20
# 34     83
# 40    269
# 41    111
# 42    124
# 43    167
# 44     97
# 45     49
# 46     84
# 47    117
#      ...
# 49    163
# 5      15
# 50     21
# 52     60
# 6       6
# 60    113
# 61     28
# 62     51
# 63     39
# 66     55
# 67     80
# 68     37
# 69      9
# 7      22
# 70     24
# 71     93
# 72     48
# 73     80
# 75    112
# 76     57
# 77     66
# 78     43
# 79     98
# 81     50
# 83     40
# 84     53
# 88     30
# 9      26
# 90     74
# 94     28
# Name: crimsusp, Length: 155, dtype: int64

# %%
police.groupby('pct').count().crimsusp.plot(kind = 'bar');
