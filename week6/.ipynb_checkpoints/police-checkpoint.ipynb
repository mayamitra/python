# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
i=[]
#generates all 3 digit numbers
for a in range(99,1000):
  #generate my second factor
    for b in range(99,1000):
      #mutliply the numbers
        c = a*b
        
        
        c = str(c)
        if c == c[::-1]:
            print(c, "Palindrome Number", i)
            i.append(c)
# Out:
# 9999 Palindrome Number []
# 54945 Palindrome Number ['9999']
# 59895 Palindrome Number ['9999', '54945']
# 64746 Palindrome Number ['9999', '54945', '59895']
# 69696 Palindrome Number ['9999', '54945', '59895', '64746']
# 74547 Palindrome Number ['9999', '54945', '59895', '64746', '69696']
# 79497 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547']
# 84348 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547', '79497']
# 89298 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547', '79497', '84348']
# 94149 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547', '79497', '84348', '89298']
# 9999 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547', '79497', '84348', '89298', '94149']
# 10201 Palindrome Number ['9999', '54945', '59895', '64746', '69696', '74547', '79497', '84348', '89298', '94149', '9999']
# ...

# %%
df = pd.read_csv('../data/week6/sqf-2017.csv')

# %%
df.head()
# Out:
#    STOP_FRISK_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2    MONTH2       DAY2  \
# 0              1       1/16/2017        14:26:00   2017   January     Monday
# 1              2       1/16/2017        14:26:00   2017   January     Monday
# 2              3        2/8/2017        11:10:00   2017  February  Wednesday
# 3              4       2/20/2017        11:35:00   2017  February     Monday
# 4              5       2/21/2017        13:20:00   2017  February    Tuesday
#
#         STOP_WAS_INITIATED SPRINT_NUMBER RECORD_STATUS_CODE  \
# 0  Based on Self Initiated      11617924                APP
# 1  Based on Self Initiated      11617924                APP
# 2    Based on C/W on Scene   17020808555                APP
# 3  Based on Self Initiated          9027                APP
# 4       Based on Radio Run         10439                APP
#
#   ISSUING_OFFICER_RANK           ...             STOP_LOCATION_SECTOR_CODE  \
# ...

# %%
df.info(verbose = True) # to show all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11629 entries, 0 to 11628
# Data columns (total 86 columns):
# STOP_FRISK_ID                                                   11629 non-null int64
# STOP_FRISK_DATE                                                 11629 non-null object
# STOP_FRISK_TIME                                                 11624 non-null object
# YEAR2                                                           11629 non-null int64
# MONTH2                                                          11629 non-null object
# DAY2                                                            11629 non-null object
# STOP_WAS_INITIATED                                              11629 non-null object
# SPRINT_NUMBER                                                   11202 non-null object
# RECORD_STATUS_CODE                                              11629 non-null object
# ISSUING_OFFICER_RANK                                            11629 non-null object
# ...

# %%
df['STOP_WAS_INITIATED'] #selects the column "Stop was initiated"
# Out:
# 0        Based on Self Initiated
# 1        Based on Self Initiated
# 2          Based on C/W on Scene
# 3        Based on Self Initiated
# 4             Based on Radio Run
# 5          Based on C/W on Scene
# 6             Based on Radio Run
# 7             Based on Radio Run
# 8             Based on Radio Run
# 9          Based on C/W on Scene
# 10         Based on C/W on Scene
# 11         Based on C/W on Scene
# 12            Based on Radio Run
# 13       Based on Self Initiated
# 14       Based on Self Initiated
# 15            Based on Radio Run
# 16         Based on C/W on Scene
# 17       Based on Self Initiated
# 18            Based on Radio Run
# 19            Based on Radio Run
# 20            Based on Radio Run
# 21            Based on Radio Run
# 22            Based on Radio Run
# 23            Based on Radio Run
# 24            Based on Radio Run
# 25       Based on Self Initiated
# 26            Based on Radio Run
# 27       Based on Self Initiated
# ...

# %%
df['STOP_WAS_INITIATED'].value_counts() 
#how many of each type of stop intitation
# Out:
# Based on Radio Run         6566
# Based on Self Initiated    3437
# Based on C/W on Scene      1612
# (null)                       13
#                               1
# Name: STOP_WAS_INITIATED, dtype: int64

# %%
df['STOP_WAS_INITIATED'] == 'Based on Self Initiated' 
#checking to see if each row is based on self initiated
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13        True
# 14        True
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25        True
# 26       False
# 27        True
# 28       False
# 29        True
#          ...
# 11599     True
# 11600     True
# 11601     True
# 11602    False
# 11603    False
# 11604    False
# 11605    False
# 11606    False
# 11607    False
# 11608     True
# 11609    False
# 11610    False
# 11611    False
# 11612    False
# 11613    False
# 11614    False
# 11615    False
# 11616    False
# 11617     True
# 11618     True
# 11619     True
# 11620    False
# 11621    False
# 11622    False
# 11623    False
# 11624    False
# 11625     True
# ...

# %%
si = df[df['STOP_WAS_INITIATED'] == 'Based on Self Initiated']
#created a new variable to save this info in --> now you can explore just this subset of data

# %%
si['SUSPECT_BODY_BUILD_TYPE'].value_counts()
# Out:
# THN    1646
# MED    1337
# HEA     300
# U       113
# (nu      32
# XXX       6
# 200       1
# 160       1
# 150       1
# Name: SUSPECT_BODY_BUILD_TYPE, dtype: int64

# %%
siplot = si['SUSPECT_BODY_BUILD_TYPE'].value_counts()

# %%
plt.plot([1,2,6,7])

# %%
siplot
# Out:
# THN    1646
# MED    1337
# HEA     300
# U       113
# (nu      32
# XXX       6
# 200       1
# 160       1
# 150       1
# Name: SUSPECT_BODY_BUILD_TYPE, dtype: int64

# %%
siplot.shape
# Out:
# (9,)

# %%
siplot.index
# Out:
# Index(['THN', 'MED', 'HEA', 'U', '(nu', 'XXX', '200', '160', '150'], dtype='object')

# %%
siplot[:4]
# Out:
# THN    1646
# MED    1337
# HEA     300
# U       113
# Name: SUSPECT_BODY_BUILD_TYPE, dtype: int64

# %%
plt.bar(siplot.index[:4], siplot[:4])
plt.xticks(rotation = 80)
# Out:
# ([0, 1, 2, 3], <a list of 4 Text xticklabel objects>)

# %%
df.OBSERVED_DURATION_MINUTES.hist()

# %%
df.OBSERVED_DURATION_MINUTES.mean()
# Out:
# 28.94083756126924

# %%
df.OBSERVED_DURATION_MINUTES.describe()
# Out:
# count    11629.000000
# mean        28.940838
# std        975.822879
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max      99999.000000
# Name: OBSERVED_DURATION_MINUTES, dtype: float64

# %%
df.SUSPECT_RACE_DESCRIPTION.value_counts()
# Out:
# BLACK             6595
# WHITE HISPANIC    2570
# BLACK HISPANIC     997
# WHITE              977
# (null)             268
# ASIAN/PAC.ISL      206
# AMER IND             9
# MALE                 7
# Name: SUSPECT_RACE_DESCRIPTION, dtype: int64
