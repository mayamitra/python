# %%
import praw

reddit = praw.Reddit(client_id='WDrvtrRuiySGWA',
                     client_secret='i4cHIuffxiJ6776-WM1ToAw2RQk',
                     user_agent='mayamitra')

# %%
import numpy as np
import pandas as pd

# %%
def get_reddit_frame(subreddit):
    Title = [] 
    Subject = []

    for submission in reddit.subreddit(subreddit).hot(limit=10):
        Title.append(submission.title)
        Subject.append(submission.subreddit)
    
    df = pd.DataFrame({'Subject': Subject, 'Title': Title})
    return df

# %%
ask_reddit = get_reddit_frame('AskReddit')
aww = get_reddit_frame('Aww')
today_I_learned = get_reddit_frame('TodayILearned')
WTF = get_reddit_frame('WTF')
made_me_smile = get_reddit_frame('mademesmile')

# %%
combo = ask_reddit.append(aww).reset_index(drop = True)

# %%
combo = combo.append(today_I_learned).reset_index(drop = True)

# %%
combo = combo.append(WTF).reset_index(drop = True)

# %%
combo = combo.append(made_me_smile).reset_index(drop = True)

# %%
combo
# Out:
#           Subject                                              Title
# 0       AskReddit  911 operators of reddit, what call will you si...
# 1       AskReddit  Teachers who regularly get invited to high sch...
# 2       AskReddit  Which book is considered a literary masterpiec...
# 3       AskReddit  Psychologists of Reddit, what is something you...
# 4       AskReddit  What are the unspoken rules of reddit that wou...
# 5       AskReddit  What is something perfectly legal that feels i...
# 6       AskReddit  Two US States go to war with each other. They ...
# 7       AskReddit  Who is your favorite figure in sports history,...
# 8       AskReddit  Paul Simon's hit song posits there must be, "5...
# 9       AskReddit  Singles of Reddit, what do you like most about...
# 10            aww  Sub of the Week: /r/animalalbumcovers, for ani...
# 11            aww  A local tv reporter here in our country brings...
# 12            aww                               Enjoying the Sunset.
# 13            aww                    Arctic fox pup after an icy dip
# 14            aww                                   Who's a good boy
# 15            aww  My dad after saying he didn’t want another dog...
# 16            aww  The first image of a black hole has been released
# 17            aww                                   Getting adopted!
# 18            aww         A fucking dog retrieving shit underwater!!
# 19            aww                                 Cuteness Emergency
# 20  todayilearned  TIL that there was a group of middle aged wome...
# 21  todayilearned  TIL That during WW2 there were around 250,000+...
# 22  todayilearned  TIL 7yr old Tyler Moon walked 1km (0.6 miles) ...
# 23  todayilearned  TIL 9/11 survivor George Mironis visits FDNY L...
# 24  todayilearned  TIL that before McDonald's switched from cooki...
# 25  todayilearned  TIL about Minnie Freeman, a teacher in Nebrask...
# 26  todayilearned  TIL India has 3 foot long, multicolored squirr...
# 27  todayilearned  TIL that actor David Herman (Michael Bolton fr...
# 28  todayilearned  TIL that 71 percent of Americans age 17 to 24 ...
# 29  todayilearned  TIL that in 2005, Eric James Torpy, was convic...
# 30            WTF                   Oh how the tables have turned...
# 31            WTF                             The Exorcism of a Thot
# 32            WTF                                                Hmm
# 33            WTF                                    Beluga with abs
# 34            WTF                Still not convinced this isn't porn
# 35            WTF                                        Terrortubby
# 36            WTF                    Bird with an arrow in its chest
# 37            WTF                                              Oh no
# 38            WTF                                  You win the part.
# 39            WTF     What in the child’s services is going on here?
# 40    MadeMeSmile                         Happiness of being adopted
# 41    MadeMeSmile                           No snakes at the library
# 42    MadeMeSmile                                 Supportive grandpa
# 43    MadeMeSmile                       Women and children +(doggos)
# 44    MadeMeSmile  It was her 95th birthday and her children surp...
# 45    MadeMeSmile                               This art piece I saw
# 46    MadeMeSmile                  Maybe one day it will all pay off
# 47    MadeMeSmile                            This just melt my heart
# 48    MadeMeSmile                                Real life heroes...
# 49    MadeMeSmile                 When He Can See Two Of His Mummy !

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
from sklearn.linear_model import LogisticRegression

# %%
cvect = CountVectorizer()
lgr = LogisticRegression()

# %%
X = combo.data
y = combo.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ece5e05c426d> in <module>
# ----> 1 X = combo.data
#       2 y = combo.target
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fdc11ba8633d> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# NameError: name 'X' is not defined
