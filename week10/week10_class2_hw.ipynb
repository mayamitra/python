# %%
import praw

reddit = praw.Reddit(client_id='WDrvtrRuiySGWA',
                     client_secret='i4cHIuffxiJ6776-WM1ToAw2RQk',
                     user_agent='mayamitra')

# %%
import numpy as np
import pandas as pd

# %%
def get_reddit_frame(subreddit):
    Title = [] 
    Subject = []

    for submission in reddit.subreddit(subreddit).hot(limit=10):
        Title.append(submission.title)
        Subject.append(submission.subreddit)
    
    df = pd.DataFrame({'Subject': Subject, 'Title': Title})
    return df

# %%
ask_reddit = get_reddit_frame('AskReddit')

# %%
aww = get_reddit_frame('Aww')

# %%
today_I_learned = get_reddit_frame('TodayILearned')

# %%
WTF = get_reddit_frame('WTF')

# %%
made_me_smile = get_reddit_frame('mademesmile')

# %%
combo = ask_reddit.append(aww).reset_index(drop = True)

# %%
combo = combo.append(today_I_learned).reset_index(drop = True)

# %%
combo = combo.append(WTF).reset_index(drop = True)

# %%
combo = combo.append(made_me_smile).reset_index(drop = True)

# %%
combo
# Out:
#           Subject                                              Title
# 0       AskReddit  Airplane pilots of Reddit, what was your bigge...
# 1       AskReddit  You win 16.99 metric tons of shrimp, what do y...
# 2       AskReddit  What's a video game you dislike that everybody...
# 3       AskReddit  What is a word that sounds dirty but actually ...
# 4       AskReddit  Everyone talks about their terrible jobs, what...
# 5       AskReddit                    Do you fear death? Why/why not?
# 6       AskReddit  What's the shittiest part about attending Hogw...
# 7       AskReddit  You gain control of Trump's Twitter account. W...
# 8       AskReddit  How would you react if, during a press confere...
# 9       AskReddit  For every person you cause to break down in te...
# 10            aww   /r/petthedamnduck: /r/Aww Subreddit of the Week!
# 11            aww        Playing the shell game with a mountain lion
# 12            aww                          Really, i love these dogs
# 13            aww                        Doggy and his favourite toy
# 14            aww                         *sound* you wont regret it
# 15            aww                  My little ruby laid her 200th egg
# 16            aww        Sleepy Boy In The Train Is Illegally Cute !
# 17            aww  I work with toucans and recently adopted a 15 ...
# 18            aww  My cat comes downstairs at 11pm every night to...
# 19            aww  Shelter puppy we liked. At first we couldn’t f...
# 20  todayilearned  TIL many people believed Abraham Lincoln was u...
# 21  todayilearned  TIL Kim Kardashian was paid to post a selfie o...
# 22  todayilearned  TIL that Teflon is the the only known material...
# 23  todayilearned  TIL Stephen Hawking spent his final days attem...
# 24  todayilearned  TIL that one of the reasons Thomas Jefferson s...
# 25  todayilearned  TIL, in 1948, a man wore 30-pound, 3-toed lead...
# 26  todayilearned  TIL that pyjamas (pajamas in the US) became fa...
# 27  todayilearned  TIL of the grasshopper mouse that hunts scorpi...
# 28  todayilearned  TIL There is a group of wolves in British Colu...
# 29  todayilearned  TIL There is a liquid that you can breathe in ...
# 30            WTF  Some guy was selling an old fridge full of Jur...
# 31            WTF                                    WTF Grandma?!?!
# 32            WTF                  This mushroom in my front yard...
# 33            WTF  My apartment in college had a tombstone of a b...
# 34            WTF                      Severe parasitic worm load...
# 35            WTF              “Mom, what’s up with grandpa’s cane?”
# 36            WTF                                   Happy Birthday!!
# 37            WTF                    Found a bird impaled in my bush
# 38            WTF                        Is this what they call art?
# 39            WTF  Our chicken laid a deformed egg that looks lik...
# 40    MadeMeSmile  Sir Patrick Stewart napping with his new foste...
# 41    MadeMeSmile                                      Absolute Bros
# 42    MadeMeSmile          What a way to honor this subreddit's name
# 43    MadeMeSmile                                What a great sister
# 44    MadeMeSmile                          Fashion do’s and don’t’s.
# 45    MadeMeSmile              Friends surmounting language barriers
# 46    MadeMeSmile          Not my post....but what a wonderful idea.
# 47    MadeMeSmile                          2 warriors After a Fight!
# 48    MadeMeSmile                                This ad on facebook
# 49    MadeMeSmile  Dad learns about selfies from daughter and the...
